# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
# Read the Excel file into a pandas DataFrame
df = pd.read_excel(r'C:\Users\hp\Downloads\BPM.xlsx', sheet_name='Sheet1')
df
# Out:
#     user  IShimmer  ISmartwatch  SShimmer  SSmartwatch  StShimmer  \
# 0      1     73.74        71.08     78.23        78.33      88.94
# 1      2     66.61        63.68     68.08        67.52      77.76
# 2      3     76.62        67.39     82.90        81.51      90.00
# 3      4     77.54        76.29     83.11        80.53     103.94
# 4      5     82.85        81.51     91.27        89.90      96.35
# 5      6     67.55        67.35     87.12        82.40      88.30
# 6      7     60.42        59.82     65.52        67.22      77.26
# 7      8     89.74        88.07     94.26        91.90     105.97
# 8      9    102.06       101.07    105.74        98.55     118.38
# 9     10     85.88        85.08     95.86        94.28     105.12
# 10    11     84.23        83.19     85.59        84.80      95.15
# 11    12     78.44        64.98     78.77        77.60      83.36
# 12    13     85.08        84.81     90.00        89.48      98.66
# ...

# %%
# # Extract the data for each sensor
# sensor1 = df['Shimmer']
# sensor2 = df['Smartwatch']

# # Extract the participant IDs
# participant_ids = df['user']
# # Drop the rows with 0 values
# df = df[(df['Shimmer'] != 0) & (df['Smartwatch'] != 0)]
# df

# %%
# Create a scatter plot
plt.scatter(participant_ids, sensor1, label='Sensor 1')
plt.scatter(participant_ids, sensor2, label='Sensor 2')

# Set the axis labels and title
plt.xlabel('Participant ID')
plt.ylabel('BPM')
plt.title('BPM estimated during Ideal Activity')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(r'C:\Users\hp\Downloads\BPM.xlsx', sheet_name='Sheet1')
df
# Out:
#     user  IShimmer  ISmartwatch  SShimmer  SSmartwatch  StShimmer  \
# 0      1     73.74        71.08     78.23        78.33      88.94
# 1      2     66.61        63.68     68.08        67.52      77.76
# 2      3     76.62        67.39     82.90        81.51      90.00
# 3      4     77.54        76.29     83.11        80.53     103.94
# 4      5     82.85        81.51     91.27        89.90      96.35
# 5      6     67.55        67.35     87.12        82.40      88.30
# 6      7     60.42        59.82     65.52        67.22      77.26
# 7      8     89.74        88.07     94.26        91.90     105.97
# 8      9    102.06       101.07    105.74        98.55     118.38
# 9     10     85.88        85.08     95.86        94.28     105.12
# 10    11     84.23        83.19     85.59        84.80      95.15
# 11    12     78.44        64.98     78.77        77.60      83.36
# 12    13     85.08        84.81     90.00        89.48      98.66
# ...

# %%
# Extract the data for each sensor
sensor1 = df['IShimmer']
sensor2 = df['ISmartwatch']

# Extract the participant IDs
participant_ids = df['user']

plt.figure(figsize=(9,5))
# Create a line plot with markers
plt.plot(participant_ids, sensor1, marker='o', label='Shimmer')
plt.plot(participant_ids, sensor2, marker='o', label='Smartwatch')

# Set the axis labels and title
plt.xlabel('Participant ID')
plt.ylabel('BPM')
plt.title('BPM data from two sensors for 30 participants')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Extract the data for each sensor
sensor1 = df['SShimmer']
sensor2 = df['SSmartwatch']

# Extract the participant IDs
participant_ids = df['user']

plt.figure(figsize=(9,5))
# Create a line plot with markers
plt.plot(participant_ids, sensor1, marker='o', label='Shimmer')
plt.plot(participant_ids, sensor2, marker='o', label='Smartwatch')

# Set the axis labels and title
plt.xlabel('Participant ID')
plt.ylabel('BPM')
plt.title('BPM data from two sensors for 30 participants')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Extract the data for each sensor
sensor1 = df['StShimmer']
sensor2 = df['StSmartwatch']

# Extract the participant IDs
participant_ids = df['user']

plt.figure(figsize=(9,5))
# Create a line plot with markers
plt.plot(participant_ids, sensor1, marker='o', label='Shimmer')
plt.plot(participant_ids, sensor2, marker='o', label='Smartwatch')

# Set the axis labels and title
plt.xlabel('Participant ID')
plt.ylabel('BPM')
plt.title('BPM data from two sensors for 30 participants')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Extract the data for each sensor
sensor1 = df['WShimmer']
sensor2 = df['WSmartwatch']

# Extract the participant IDs
participant_ids = df['user']

plt.figure(figsize=(9,5))
# Create a line plot with markers
plt.plot(participant_ids, sensor1, marker='o', label='Shimmer')
plt.plot(participant_ids, sensor2, marker='o', label='Smartwatch')

# Set the axis labels and title
plt.xlabel('Participant ID')
plt.ylabel('BPM')
plt.title('BPM data from two sensors for 30 participants')

# Add a legend
plt.legend()

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel(r'C:\Users\hp\Downloads\BPM.xlsx', sheet_name='Sheet1')
df

# Define the list of column pairs to plot in each subplot
column_pairs = [("IShimmer", "ISmartwatch"), 
                ("SShimmer", "SSmartwatch"),  
                ("StShimmer", "StSmartwatch"),  
               ("WShimmer", "WSmartwatch")]

# Create a 2 by 2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Loop over each subplot and plot the corresponding column pair
for i, ax in enumerate(axs.flat):
    if i < len(column_pairs):
        column1, column2 = column_pairs[i]
        df.plot(x="user", y=[column1, column2], ax=ax,marker="o",legend=False, color=['#1f77b4', '#ff7f0e'])

axs[0, 0].set_title("Ideal")        
axs[0, 1].set_title("Sitting")
axs[1, 0].set_title("Standing")
axs[1, 1].set_title("Walking")
axs[0, 0].set_ylabel("BPM")
axs[1, 0].set_ylabel("BPM")
# Create a legend using proxy artists
legend_colors = ['#1f77b4', '#ff7f0e']
legend_labels = ['Shimmer', 'Smartwatch']
handles = [plt.Line2D([], [], color=c) for c in legend_colors]
plt.legend(handles, legend_labels, loc='center left', bbox_to_anchor=(0.7,-0.25))


# Adjust the layout and show the plot
plt.tight_layout()
plt.savefig('heartcomp.png', dpi=800)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
import numpy as np
# Calculate the difference in BPM between the Shimmer sensor and the smartwatch for each data point
a = df['IShimmer'] - df['ISmartwatch']

# Calculate the average of the absolute values of the BPM differences to get the average error
average_error = abs(a).mean()

std_deviation = np.std(a)

print(f"The average absolute error in BPM between the Shimmer sensor and the smartwatch is {average_error:.2f}")
print(f"The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is {std_deviation:.2f}")
# Out:
# The average absolute error in BPM between the Shimmer sensor and the smartwatch is 2.15
# The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is 2.93

# %%
# Calculate the difference in BPM between the Shimmer sensor and the smartwatch for each data point
a = df['SShimmer'] - df['SSmartwatch']

# Calculate the average of the absolute values of the BPM differences to get the average error
average_error = abs(a).mean()
std_deviation = np.std(a)

print(f"The average absolute error in BPM between the Shimmer sensor and the smartwatch is {average_error:.2f}")
print(f"The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is {std_deviation:.2f}")
# Out:
# The average absolute error in BPM between the Shimmer sensor and the smartwatch is 2.57
# The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is 2.05

# %%
# Calculate the difference in BPM between the Shimmer sensor and the smartwatch for each data point
a = df['StShimmer'] - df['StSmartwatch']

# Calculate the average of the absolute values of the BPM differences to get the average error
average_error = abs(a).mean()
std_deviation = np.std(a)

print(f"The average absolute error in BPM between the Shimmer sensor and the smartwatch is {average_error:.2f}")
print(f"The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is {std_deviation:.2f}")
# Out:
# The average absolute error in BPM between the Shimmer sensor and the smartwatch is 9.07
# The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is 22.37

# %%
# Calculate the difference in BPM between the Shimmer sensor and the smartwatch for each data point
a = df['WShimmer'] - df['WSmartwatch']

# Calculate the average of the absolute values of the BPM differences to get the average error
average_error = abs(a).mean()

print(f"The average error in BPM between the Shimmer sensor and the smartwatch is {average_error:.2f}")
# Out:
# The average error in BPM between the Shimmer sensor and the smartwatch is 38.26

# %%
# Calculate the difference in BPM between the Shimmer sensor and the smartwatch for each data point
a = df['WShimmer'] - df['WSmartwatch']

# Calculate the average of the absolute values of the BPM differences to get the average error
average_error = abs(a).mean()
std_deviation = np.std(a)

print(f"The average absolute error in BPM between the Shimmer sensor and the smartwatch is {average_error:.2f}")
print(f"The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is {std_deviation:.2f}")
bpm_estimation_error = abs(merged_data['bpm_diff']).sum() / len(merged_data)
# Out:
# The average absolute error in BPM between the Shimmer sensor and the smartwatch is 69.15
# The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is 63.25
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14840\3815122418.py in <module>
#       8 print(f"The average absolute error in BPM between the Shimmer sensor and the smartwatch is {average_error:.2f}")
#       9 print(f"The standard deviation of the error in BPM between the Shimmer sensor and the smartwatch is {std_deviation:.2f}")
# ---> 10 bpm_estimation_error = abs(merged_data['bpm_diff']).sum() / len(merged_data)
#
# NameError: name 'merged_data' is not defined
